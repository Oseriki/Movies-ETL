# %%
import pandas as pd

# %%
#kaggle_metadata_df = pd.read_csv('movies_metadata.csv', low_memory=False)
#ratings_df = pd.read_csv('ratings.csv')

# Make a reference to the books.csv file path
kaggle_metadata_to_load = "Resources/movies_metadata.csv"
ratings_data_to_load = "Resources/ratings.csv"

kaggle_metadata_df = pd.read_csv(kaggle_metadata_to_load, low_memory=False)
ratings_df = pd.read_csv(ratings_data_to_load)

# %%
kaggle_metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata_df.sample(n=5)
# Out:
#        adult belongs_to_collection    budget  \
# 45233  False                   NaN         0
# 32184  False                   NaN    170000
# 22737  False                   NaN         0
# 33940  False                   NaN         0
# 4918   False                   NaN  33000000
#
#                                                   genres  \
# 45233  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 32184                      [{'id': 18, 'name': 'Drama'}]
# 22737  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 33940  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
# 4918   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
#
#                                            homepage      id    imdb_id  \
# 45233    http://thegirlfromthesongmovie.tumblr.com/  454774  tt6336270
# 32184                                           NaN  250312  tt3379358
# 22737                                           NaN    2594  tt0291400
# 33940  http://www.officialrejectiondocumentary.com/   59333  tt0780577
# 4918                                            NaN   11888  tt0281373
#
#       original_language                 original_title  \
# 45233                en         The Girl from the Song
# 32184                th  Mary Is Happy, Mary Is Happy.
# 22737                fr             Monsieur Batignole
# 33940                en             Official Rejection
# 4918                 en                      Snow Dogs
#
#                                                 overview  ... release_date  \
# 45233  A young musician travels to Burning Man, a psy...  ...   2017-04-24
# 32184  Mary is a senior in high school. With graduati...  ...   2013-09-01
# 22737  In 1942, in an occupied Paris, the apolitical ...  ...   2002-03-06
# 33940  A documentary following the exploits of a grou...  ...   2009-04-04
# 4918   When a Miami dentist inherits a team of sled d...  ...   2002-01-18
#
#       revenue runtime                                   spoken_languages  \
# 45233     0.0   102.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 32184     0.0   127.0           [{'iso_639_1': 'th', 'name': 'ภาษาไทย'}]
# 22737     0.0   100.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 33940     0.0   108.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4918      0.0    99.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                    tagline  \
# 45233  Released                                        NaN
# 32184  Released                                        NaN
# 22737  Released                                        NaN
# 33940  Released  When the shooting stops... the war begins
# 4918   Released                   Get ready for mush hour!
#
#                                title  video vote_average vote_count
# 45233         The Girl from the Song  False          6.3        4.0
# 32184  Mary Is Happy, Mary Is Happy.  False          7.3        7.0
# 22737             Monsieur Batignole  False          7.0       51.0
# 33940             Official Rejection  False          2.5        2.0
# 4918                       Snow Dogs  False          5.3      190.0
#
# [5 rows x 24 columns]

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings_df.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 13174536  136912      750     5.0  1003284790
# 214170      2306     7247     3.5  1435848016
# 18105264  187960      265     2.0  1111288172
# 4529988    46498      953     3.0  1131188612
# 24437147  253947      586     3.5  1149034345
