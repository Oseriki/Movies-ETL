# %%
import pandas as pd

# %%
#kaggle_metadata_df = pd.read_csv('movies_metadata.csv', low_memory=False)
#ratings_df = pd.read_csv('ratings.csv')

# Make a reference to the books.csv file path
kaggle_metadata_to_load = "Resources/movies_metadata.csv"
ratings_data_to_load = "Resources/ratings.csv"

kaggle_metadata_df = pd.read_csv(kaggle_metadata_to_load, low_memory=False)
ratings_df = pd.read_csv(ratings_data_to_load)

# %%
kaggle_metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata_df.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 40358  False                   NaN      0
# 30748  False                   NaN      0
# 7802   False                   NaN      0
# 44807  False                   NaN      0
# 43845  False                   NaN      0
#
#                                                   genres homepage      id  \
# 40358                     [{'id': 35, 'name': 'Comedy'}]      NaN  352582
# 30748                     [{'id': 27, 'name': 'Horror'}]      NaN  104108
# 7802   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN   15794
# 44807  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...      NaN  437311
# 43845  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...      NaN   62196
#
#          imdb_id original_language   original_title  \
# 40358  tt3505754                en        Bachelors
# 30748  tt1291521                en      The Craving
# 7802   tt0042041                en       White Heat
# 44807  tt3469798                es         Órbita 9
# 43845  tt1504489                en  Somebody's Hero
#
#                                                 overview  ... release_date  \
# 40358  Womanizing advertising executive Aaron tries t...  ...   2016-10-06
# 30748  A group of college students embarking on a cro...  ...   2008-01-01
# 7802   A psychopathic criminal (Cagney) with a mother...  ...   1949-09-02
# 44807  A girl discovers that the reality of her life ...  ...   2017-04-07
# 43845  An average New York accountant tries to fill t...  ...   2011-05-01
#
#       revenue runtime                          spoken_languages    status  \
# 40358     0.0    86.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 30748     0.0    98.0                                        []  Released
# 7802      0.0   114.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 44807     0.0    95.0  [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 43845     0.0     0.0                                        []  Released
#
#                                                  tagline            title  \
# 40358  While hosting his best friend's bachelor party...        Bachelors
# 30748                                                NaN      The Craving
# 7802   Pick up the pieces folks, Jimmy's in action ag...       White Heat
# 44807                             Love will set you free        Orbiter 9
# 43845                       Everybody is Somebody's Hero  Somebody's Hero
#
#        video vote_average vote_count
# 40358  False          4.2        6.0
# 30748  False          7.0        1.0
# 7802   False          7.8       92.0
# 44807  False          5.5       24.0
# 43845  False          6.1        6.0
#
# [5 rows x 24 columns]

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings_df.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 1558497    16095     5971     5.0  1286212064
# 24611749  255810     3730     4.0   974743566
# 4915446    50605    60069     4.0  1285249465
# 22654210  235394    71254     5.0  1357335369
# 22546528  234142     4643     0.5  1144277327
