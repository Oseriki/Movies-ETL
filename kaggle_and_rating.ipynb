# %%
import pandas as pd

# %%
#kaggle_metadata_df = pd.read_csv('movies_metadata.csv', low_memory=False)
#ratings_df = pd.read_csv('ratings.csv')

# Make a reference to the books.csv file path
kaggle_metadata_to_load = "Resources/movies_metadata.csv"
ratings_data_to_load = "Resources/ratings.csv"

kaggle_metadata_df = pd.read_csv(kaggle_metadata_to_load, low_memory=False)
ratings_df = pd.read_csv(ratings_data_to_load)

# %%
kaggle_metadata_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
kaggle_metadata_df.sample(n=5)
# Out:
#        adult                              belongs_to_collection    budget  \
# 23997  False                                                NaN         0
# 34025  False  {'id': 88735, 'name': 'K-9 Collection', 'poste...         0
# 8893   False                                                NaN  25000000
# 15249  False                                                NaN         0
# 20843  False                                                NaN  40000000
#
#                                                   genres homepage      id  \
# 23997  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...      NaN  245184
# 34025  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN   47354
# 8893            [{'id': 878, 'name': 'Science Fiction'}]      NaN   36677
# 15249                                                 []      NaN   37255
# 20843  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...      NaN   77221
#
#          imdb_id original_language           original_title  \
# ...

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings_df.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 15002283  156042    98239     3.5  1426921182
# 6427167    66349     7897     3.5  1254137940
# 4247570    44095     2329     4.5  1356509742
# 21029731  218559     7361     4.5  1312901790
# 8538424    87979      931     4.0  1083675680

# %%
kaggle_metadata_df.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object
